# %%
import pandas as pd
import numpy as np
import datetime

# %%
features = pd.read_excel('https://query.data.world/s/2hymngpmogoje5bwt3ikufdxjdgkn3')
features.head()
# Out:
#                                               SongID  \
# 0                      AdictoTainy, Anuel AA & Ozuna
# 1  The Ones That Didn't Make It Back HomeJustin M...
# 2                  ShallowLady Gaga & Bradley Cooper
# 3                EnemiesPost Malone Featuring DaBaby
# 4    Bacc At It AgainYella Beezy, Gucci Mane & Quavo
#
#                          Performer                                    Song  \
# 0          Tainy, Anuel AA & Ozuna                                  Adicto
# 1                     Justin Moore  The Ones That Didn't Make It Back Home
# 2       Lady Gaga & Bradley Cooper                                 Shallow
# 3     Post Malone Featuring DaBaby                                 Enemies
# 4  Yella Beezy, Gucci Mane & Quavo                        Bacc At It Again
#
#                                        spotify_genre        spotify_track_id  \
# 0                                  ['pop reggaeton']  3jbT1Y5MoPwEIpZndDDwVq
# 1  ['arkansas country', 'contemporary country', '...                     NaN
# 2                               ['dance pop', 'pop']  2VxeLyX666F8uXCJ0dZF8B
# 3                  ['dfw rap', 'melodic rap', 'rap']  0Xek5rqai2jcOWCYWJfVCF
# 4     ['dfw rap', 'rap', 'southern hip hop', 'trap']  2biNa12dMbHJrHVFRt8JyO
#
#                            spotify_track_preview_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://p.scdn.co/mp3-preview/fa6fa6f6f363be29...
#
#               spotify_track_album  spotify_track_explicit  \
# 0  Adicto (with Anuel AA & Ozuna)                     0.0
# 1                             NaN                     NaN
# 2       A Star Is Born Soundtrack                     0.0
# 3            Hollywood's Bleeding                     1.0
# 4                Bacc At It Again                     1.0
#
#    spotify_track_duration_ms  spotify_track_popularity  ...   key  loudness  \
# 0                   270740.0                      91.0  ...  10.0    -4.803
# 1                        NaN                       NaN  ...   NaN       NaN
# 2                   215733.0                      88.0  ...   7.0    -6.362
# 3                   196760.0                      86.0  ...   6.0    -4.169
# 4                   228185.0                      61.0  ...   8.0    -5.725
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   0.0       0.0735       0.01700          0.000016    0.1790    0.623
# 1   NaN          NaN           NaN               NaN       NaN      NaN
# 2   1.0       0.0308       0.37100          0.000000    0.2310    0.323
# 3   1.0       0.2100       0.05880          0.000000    0.0955    0.667
# 4   0.0       0.1680       0.00124          0.000001    0.0716    0.856
#
#      tempo  time_signature
# 0   80.002             4.0
# 1      NaN             NaN
# 2   95.799             4.0
# 3   76.388             4.0
# 4  135.979             4.0
#
# [5 rows x 22 columns]

# %%
features = features[~features['spotify_track_id'].isnull()][features.columns[0:5]].drop_duplicates()
features.head()
# Out:
#                                             SongID  \
# 0                    AdictoTainy, Anuel AA & Ozuna
# 2                ShallowLady Gaga & Bradley Cooper
# 3              EnemiesPost Malone Featuring DaBaby
# 4  Bacc At It AgainYella Beezy, Gucci Mane & Quavo
# 5                           The ArcherTaylor Swift
#
#                          Performer              Song  \
# 0          Tainy, Anuel AA & Ozuna            Adicto
# 2       Lady Gaga & Bradley Cooper           Shallow
# 3     Post Malone Featuring DaBaby           Enemies
# 4  Yella Beezy, Gucci Mane & Quavo  Bacc At It Again
# 5                     Taylor Swift        The Archer
#
#                                     spotify_genre        spotify_track_id
# 0                               ['pop reggaeton']  3jbT1Y5MoPwEIpZndDDwVq
# 2                            ['dance pop', 'pop']  2VxeLyX666F8uXCJ0dZF8B
# 3               ['dfw rap', 'melodic rap', 'rap']  0Xek5rqai2jcOWCYWJfVCF
# 4  ['dfw rap', 'rap', 'southern hip hop', 'trap']  2biNa12dMbHJrHVFRt8JyO
# 5           ['dance pop', 'pop', 'post-teen pop']  3pHkh7d0lzM2AldUtz2x37

# %%
stuff = pd.read_csv('https://query.data.world/s/go22golrhaeqllglpuxnnd7irb3l2j')
stuff['WeekID'] = pd.to_datetime(stuff['WeekID'])
stuff.head()
# Out:
#                                                  url     WeekID  \
# 0  http://www.billboard.com/charts/hot-100/1963-0... 1963-06-01
# 1  http://www.billboard.com/charts/hot-100/1967-0... 1967-01-07
# 2  http://www.billboard.com/charts/hot-100/1971-0... 1971-07-03
# 3  http://www.billboard.com/charts/hot-100/1975-1... 1975-11-29
# 4  http://www.billboard.com/charts/hot-100/1979-0... 1979-09-29
#
#    Week Position                          Song         Performer  \
# 0             11                         Still     Bill Anderson
# 1             11           Coming Home Soldier      Bobby Vinton
# 2             11  She's Not Just Another Woman       The 8th Day
# 3             11                Saturday Night  Bay City Rollers
# 4             11                     Pop Muzik                 M
#
#                                     SongID  Instance  Previous Week Position  \
# 0                       StillBill Anderson       1.0                    17.0
# 1          Coming Home SoldierBobby Vinton       1.0                    17.0
# 2  She's Not Just Another WomanThe 8th Day       1.0                    17.0
# 3           Saturday NightBay City Rollers       1.0                    17.0
# 4                               Pop MuzikM       1.0                    17.0
#
#    Peak Position  Weeks on Chart
# 0           11.0             8.0
# 1           11.0             8.0
# 2           11.0             8.0
# 3           11.0             8.0
# 4           11.0             8.0

# %%
#stuff.groupby(by=['SongID']).describe()

# %%
avg_pos = stuff[['WeekID', 'Week Position', 'SongID']].groupby(by=['SongID']).mean()
avg_pos
# Out:
#                                                     Week Position
# SongID
# "B" GirlsYoung And Restless                             71.000000
# "Cherry Cherry" from Hot August NightNeil Diamond       47.900000
# "Having A Party" MedleyThe Ovations (Featuring ...      76.000000
# "Joy" Pt. IIsaac Hayes                                  42.222222
# "Roots" MedleyQuincy Jones                              70.571429
# ...                                                           ...
# teachmeMusiq Soulchild                                  60.750000
# whoa (mind in awe)XXXTENTACION                          70.666667
# whoknowsMusiq                                           84.461538
# www.memoryAlan Jackson                                  63.400000
# ¿Dònde Està Santa Claus? (Where Is Santa Claus?...      53.250000
#
# [29154 rows x 1 columns]

# %%
minweek = stuff[['WeekID', 'SongID']].groupby(by=['SongID']).min().rename(columns={'WeekID':'firstWeekID'})
minweek
# Out:
#                                                    firstWeekID
# SongID
# "B" GirlsYoung And Restless                         1990-05-05
# "Cherry Cherry" from Hot August NightNeil Diamond   1973-03-17
# "Having A Party" MedleyThe Ovations (Featuring ...  1973-10-13
# "Joy" Pt. IIsaac Hayes                              1973-12-22
# "Roots" MedleyQuincy Jones                          1977-03-05
# ...                                                        ...
# teachmeMusiq Soulchild                              2007-05-26
# whoa (mind in awe)XXXTENTACION                      2018-12-22
# whoknowsMusiq                                       2004-04-24
# www.memoryAlan Jackson                              2000-11-04
# ¿Dònde Està Santa Claus? (Where Is Santa Claus?...  1958-12-13
#
# [29154 rows x 1 columns]

# %%
maxweek = stuff[['WeekID', 'SongID']].groupby(by=['SongID']).max().rename(columns={'WeekID':'lastWeekID'})
maxweek
# Out:
#                                                    lastWeekID
# SongID
# "B" GirlsYoung And Restless                        1990-08-11
# "Cherry Cherry" from Hot August NightNeil Diamond  1973-05-19
# "Having A Party" MedleyThe Ovations (Featuring ... 1973-12-08
# "Joy" Pt. IIsaac Hayes                             1974-02-16
# "Roots" MedleyQuincy Jones                         1977-04-16
# ...                                                       ...
# teachmeMusiq Soulchild                             2007-10-06
# whoa (mind in awe)XXXTENTACION                     2019-01-12
# whoknowsMusiq                                      2004-07-17
# www.memoryAlan Jackson                             2001-02-10
# ¿Dònde Està Santa Claus? (Where Is Santa Claus?... 1959-01-03
#
# [29154 rows x 1 columns]

# %%
max_occ = stuff[['SongID','Instance','Weeks on Chart']].groupby(by=['SongID']).max()
max_occ
# Out:
#                                                     Instance  Weeks on Chart
# SongID
# "B" GirlsYoung And Restless                              1.0            15.0
# "Cherry Cherry" from Hot August NightNeil Diamond        1.0            10.0
# "Having A Party" MedleyThe Ovations (Featuring ...       1.0             9.0
# "Joy" Pt. IIsaac Hayes                                   1.0             9.0
# "Roots" MedleyQuincy Jones                               1.0             7.0
# ...                                                      ...             ...
# teachmeMusiq Soulchild                                   1.0            20.0
# whoa (mind in awe)XXXTENTACION                           2.0             3.0
# whoknowsMusiq                                            1.0            13.0
# www.memoryAlan Jackson                                   1.0            15.0
# ¿Dònde Està Santa Claus? (Where Is Santa Claus?...       1.0             4.0
#
# [29154 rows x 2 columns]

# %%
stats = avg_pos.join(minweek).join(maxweek).join(max_occ)
stats
# Out:
#                                                     Week Position firstWeekID  \
# SongID
# "B" GirlsYoung And Restless                             71.000000  1990-05-05
# "Cherry Cherry" from Hot August NightNeil Diamond       47.900000  1973-03-17
# "Having A Party" MedleyThe Ovations (Featuring ...      76.000000  1973-10-13
# "Joy" Pt. IIsaac Hayes                                  42.222222  1973-12-22
# "Roots" MedleyQuincy Jones                              70.571429  1977-03-05
# ...                                                           ...         ...
# teachmeMusiq Soulchild                                  60.750000  2007-05-26
# whoa (mind in awe)XXXTENTACION                          70.666667  2018-12-22
# whoknowsMusiq                                           84.461538  2004-04-24
# www.memoryAlan Jackson                                  63.400000  2000-11-04
# ¿Dònde Està Santa Claus? (Where Is Santa Claus?...      53.250000  1958-12-13
#
#                                                    lastWeekID  Instance  \
# SongID
# "B" GirlsYoung And Restless                        1990-08-11       1.0
# "Cherry Cherry" from Hot August NightNeil Diamond  1973-05-19       1.0
# "Having A Party" MedleyThe Ovations (Featuring ... 1973-12-08       1.0
# "Joy" Pt. IIsaac Hayes                             1974-02-16       1.0
# "Roots" MedleyQuincy Jones                         1977-04-16       1.0
# ...                                                       ...       ...
# teachmeMusiq Soulchild                             2007-10-06       1.0
# whoa (mind in awe)XXXTENTACION                     2019-01-12       2.0
# whoknowsMusiq                                      2004-07-17       1.0
# www.memoryAlan Jackson                             2001-02-10       1.0
# ¿Dònde Està Santa Claus? (Where Is Santa Claus?... 1959-01-03       1.0
#
#                                                     Weeks on Chart
# SongID
# "B" GirlsYoung And Restless                                   15.0
# "Cherry Cherry" from Hot August NightNeil Diamond             10.0
# "Having A Party" MedleyThe Ovations (Featuring ...             9.0
# "Joy" Pt. IIsaac Hayes                                         9.0
# "Roots" MedleyQuincy Jones                                     7.0
# ...                                                            ...
# teachmeMusiq Soulchild                                        20.0
# whoa (mind in awe)XXXTENTACION                                 3.0
# whoknowsMusiq                                                 13.0
# www.memoryAlan Jackson                                        15.0
# ¿Dònde Està Santa Claus? (Where Is Santa Claus?...             4.0
#
# [29154 rows x 5 columns]

# %%
data = features.join(stats,on='SongID').rename(columns={'Week Position':'Avg Weekly'})
data.head()
# Out:
#                                             SongID  \
# 0                    AdictoTainy, Anuel AA & Ozuna
# 2                ShallowLady Gaga & Bradley Cooper
# 3              EnemiesPost Malone Featuring DaBaby
# 4  Bacc At It AgainYella Beezy, Gucci Mane & Quavo
# 5                           The ArcherTaylor Swift
#
#                          Performer              Song  \
# 0          Tainy, Anuel AA & Ozuna            Adicto
# 2       Lady Gaga & Bradley Cooper           Shallow
# 3     Post Malone Featuring DaBaby           Enemies
# 4  Yella Beezy, Gucci Mane & Quavo  Bacc At It Again
# 5                     Taylor Swift        The Archer
#
#                                     spotify_genre        spotify_track_id  \
# 0                               ['pop reggaeton']  3jbT1Y5MoPwEIpZndDDwVq
# 2                            ['dance pop', 'pop']  2VxeLyX666F8uXCJ0dZF8B
# 3               ['dfw rap', 'melodic rap', 'rap']  0Xek5rqai2jcOWCYWJfVCF
# 4  ['dfw rap', 'rap', 'southern hip hop', 'trap']  2biNa12dMbHJrHVFRt8JyO
# 5           ['dance pop', 'pop', 'post-teen pop']  3pHkh7d0lzM2AldUtz2x37
#
#    Avg Weekly firstWeekID lastWeekID  Instance  Weeks on Chart
# 0   92.000000  2019-10-05 2019-10-12       1.0             2.0
# 2   26.377778  2018-10-13 2019-08-17       1.0            45.0
# 3   66.166667  2019-09-21 2020-01-18       1.0            15.0
# 4   91.500000  2019-06-08 2019-07-13       1.0             6.0
# 5   62.000000  2019-08-03 2019-09-07       2.0             3.0

# %%
d1 = data[(data['firstWeekID'] < datetime.datetime(2019, 12, 31)) & (data['lastWeekID'] > datetime.datetime(2019, 1, 1))]
d1 = d1.dropna().reset_index(drop=True)
d1
# Out:
#                                               SongID  \
# 0                      AdictoTainy, Anuel AA & Ozuna
# 1                  ShallowLady Gaga & Bradley Cooper
# 2                EnemiesPost Malone Featuring DaBaby
# 3    Bacc At It AgainYella Beezy, Gucci Mane & Quavo
# 4                             The ArcherTaylor Swift
# ..                                               ...
# 600                             You SayLauren Daigle
# 601        You Should See Me In A CrownBillie Eilish
# 602                                      YouJacquees
# 603                    Youngblood5 Seconds Of Summer
# 604  ZEZEKodak Black Featuring Travis Scott & Offset
#
#                                        Performer  \
# 0                        Tainy, Anuel AA & Ozuna
# 1                     Lady Gaga & Bradley Cooper
# 2                   Post Malone Featuring DaBaby
# 3                Yella Beezy, Gucci Mane & Quavo
# 4                                   Taylor Swift
# ..                                           ...
# 600                                Lauren Daigle
# 601                                Billie Eilish
# 602                                     Jacquees
# 603                          5 Seconds Of Summer
# 604  Kodak Black Featuring Travis Scott & Offset
#
#                              Song  \
# 0                          Adicto
# 1                         Shallow
# 2                         Enemies
# 3                Bacc At It Again
# 4                      The Archer
# ..                            ...
# 600                       You Say
# 601  You Should See Me In A Crown
# 602                           You
# 603                    Youngblood
# 604                          ZEZE
#
#                                          spotify_genre  \
# 0                                    ['pop reggaeton']
# 1                                 ['dance pop', 'pop']
# 2                    ['dfw rap', 'melodic rap', 'rap']
# 3       ['dfw rap', 'rap', 'southern hip hop', 'trap']
# 4                ['dance pop', 'pop', 'post-teen pop']
# ..                                                 ...
# 600              ['ccm', 'christian music', 'worship']
# 601                              ['electropop', 'pop']
# 602  ['atl hip hop', 'deep pop r&b', 'pop', 'pop ra...
# 603  ['boy band', 'dance pop', 'pop', 'post-teen pop']
# 604  ['florida rap', 'hip hop', 'melodic rap', 'mia...
#
#            spotify_track_id  Avg Weekly firstWeekID lastWeekID  Instance  \
# 0    3jbT1Y5MoPwEIpZndDDwVq   92.000000  2019-10-05 2019-10-12       1.0
# 1    2VxeLyX666F8uXCJ0dZF8B   26.377778  2018-10-13 2019-08-17       1.0
# 2    0Xek5rqai2jcOWCYWJfVCF   66.166667  2019-09-21 2020-01-18       1.0
# 3    2biNa12dMbHJrHVFRt8JyO   91.500000  2019-06-08 2019-07-13       1.0
# 4    3pHkh7d0lzM2AldUtz2x37   62.000000  2019-08-03 2019-09-07       2.0
# ..                      ...         ...         ...        ...       ...
# 600  6Up545NUflOiXo8cEraH49   52.395349  2018-07-28 2019-05-18       1.0
# 601  3XF5xLJHOQQRbWya6hBp7d   73.750000  2018-08-04 2019-05-25       2.0
# 602  01jIO8SJFnpSiNLH1JaBZ5   74.000000  2018-12-08 2019-02-23       1.0
# 603  2iUXsYOEPhVqEBwsqP70rE   27.000000  2018-06-16 2019-05-11       1.0
# 604  0FZ4Dmg8jJJAPJnvBIzD9z   16.240000  2018-10-27 2019-04-13       1.0
#
#      Weeks on Chart
# 0               2.0
# 1              45.0
# 2              15.0
# 3               6.0
# 4               3.0
# ..              ...
# 600            43.0
# 601             8.0
# 602            12.0
# 603            48.0
# 604            25.0
#
# [605 rows x 10 columns]

# %%
d1['spotify_genre'] = [x.strip('[]').strip('\'').split('\', \'') for x in d1['spotify_genre']]

# %%
selection = ['pop', 'dance pop']
#pd.DataFrame(d1.spotify_genre.tolist()).isin(selection).any(1).values
d1[d1.spotify_genre.apply(lambda x: bool(set(x) & set(selection)))]
# Out:
#                                                 SongID  \
# 1                    ShallowLady Gaga & Bradley Cooper
# 4                               The ArcherTaylor Swift
# 9                          Cornelia StreetTaylor Swift
# 10                     HeatChris Brown Featuring Gunna
# 11                           Yellow HeartsAnt Saunders
# ..                                                 ...
# 593  Weather The StormDJ Khaled Featuring Meek Mill...
# 597  This FeelingThe Chainsmokers Featuring Kelsea ...
# 601          You Should See Me In A CrownBillie Eilish
# 602                                        YouJacquees
# 603                      Youngblood5 Seconds Of Summer
#
#                                        Performer  \
# 1                     Lady Gaga & Bradley Cooper
# 4                                   Taylor Swift
# 9                                   Taylor Swift
# 10                   Chris Brown Featuring Gunna
# 11                                  Ant Saunders
# ..                                           ...
# 593     DJ Khaled Featuring Meek Mill & Lil Baby
# 597  The Chainsmokers Featuring Kelsea Ballerini
# 601                                Billie Eilish
# 602                                     Jacquees
# 603                          5 Seconds Of Summer
#
#                              Song  \
# 1                         Shallow
# 4                      The Archer
# 9                 Cornelia Street
# 10                           Heat
# 11                  Yellow Hearts
# ..                            ...
# 593             Weather The Storm
# 597                  This Feeling
# 601  You Should See Me In A Crown
# 602                           You
# 603                    Youngblood
#
#                                          spotify_genre  \
# 1                                     [dance pop, pop]
# 4                      [dance pop, pop, post-teen pop]
# 9                      [dance pop, pop, post-teen pop]
# 10                 [dance pop, pop, pop rap, r&b, rap]
# 11                                               [pop]
# ..                                                 ...
# 593  [dance pop, hip hop, miami hip hop, pop, pop r...
# 597                  [electropop, pop, tropical house]
# 601                                  [electropop, pop]
# 602  [atl hip hop, deep pop r&b, pop, pop rap, r&b,...
# 603          [boy band, dance pop, pop, post-teen pop]
#
#            spotify_track_id  Avg Weekly firstWeekID lastWeekID  Instance  \
# 1    2VxeLyX666F8uXCJ0dZF8B   26.377778  2018-10-13 2019-08-17       1.0
# 4    3pHkh7d0lzM2AldUtz2x37   62.000000  2019-08-03 2019-09-07       2.0
# 9    12M5uqx0ZuwkpLp5rJim1a   57.000000  2019-09-07 2019-09-07       1.0
# 10   1GIYmwtBbPSHrqcSaukZck   52.600000  2019-09-14 2020-01-25       1.0
# 11   2W4yABdLc4Jnds67Poi5Nl   91.125000  2019-11-23 2020-01-11       1.0
# ..                      ...         ...         ...        ...       ...
# 593  6xVhqLT40s5sVhepe9Mckc   91.000000  2019-06-01 2019-06-01       1.0
# 597  4NBTZtAt1F13VvlSKe6KTl   70.350000  2018-10-06 2019-03-09       3.0
# 601  3XF5xLJHOQQRbWya6hBp7d   73.750000  2018-08-04 2019-05-25       2.0
# 602  01jIO8SJFnpSiNLH1JaBZ5   74.000000  2018-12-08 2019-02-23       1.0
# 603  2iUXsYOEPhVqEBwsqP70rE   27.000000  2018-06-16 2019-05-11       1.0
#
#      Weeks on Chart
# 1              45.0
# 4               3.0
# 9               1.0
# 10             16.0
# 11              6.0
# ..              ...
# 593             1.0
# 597            20.0
# 601             8.0
# 602            12.0
# 603            48.0
#
# [212 rows x 10 columns]

# %%
# import time

# t0 = time.time()

import pandas as pd
import numpy as np
import datetime

class billboard:
    def __init__(self):
        #features = pd.read_csv('Hot 100 Audio Features.csv')
        f = pd.read_excel('https://query.data.world/s/2hymngpmogoje5bwt3ikufdxjdgkn3')
        # only include tracks that have a spotify id on file for now
        #f = f[~f['spotify_track_id'].isnull()][f.columns[0:5]].drop_duplicates()
        f = f.dropna(subset=['spotify_track_id', 'spotify_genre'])[f.columns[0:5]].drop_duplicates()
        f['spotify_genre'] = [x.strip('[]').strip('\'').split('\', \'') for x in f['spotify_genre']]
        self.features = f

        #stuff = pd.read_csv('Hot Stuff.csv')
        stuff = pd.read_csv('https://query.data.world/s/go22golrhaeqllglpuxnnd7irb3l2j')
        stuff['WeekID'] = pd.to_datetime(stuff['WeekID'])
        self.stuff = stuff

    def weeklyAvg(self):
        # average weekly position
        avg_pos = self.stuff[['WeekID', 'Week Position', 'SongID']].groupby(by=['SongID']).mean()
        # first week the track appeared in the chart
        minweek = self.stuff[['WeekID', 'SongID']].groupby(by=['SongID']).min().rename(columns={'WeekID':'firstWeekID'})
        # last week the track appeared in the chart
        maxweek = self.stuff[['WeekID', 'SongID']].groupby(by=['SongID']).max().rename(columns={'WeekID':'lastWeekID'})
        # total # of weeks the track was in the chart
        max_occ = self.stuff[['SongID','Instance','Weeks on Chart']].groupby(by=['SongID']).max()

        stats = avg_pos.join(minweek).join(maxweek).join(max_occ)
        self.data = self.features.join(stats, on='SongID').rename(columns={'Week Position':'Avg Weekly'})

    def getList(self, how='avg', length=30, genre=['pop','dance pop'], startY=2019, startM=1, startD=1, endY=2019, endM=12, endD=31):
        # songs should have left chart after lower bound (e.g. 2019 songs should still be on chart after 2019/1/1)
        lowerBound = datetime.datetime(startY, startM, startD)
        # songs should have entered chart before upper bound (e.g. 2019 songs should have been on chart before 2019/12/31)
        upperBound = datetime.datetime(endY, endM, endD)

        #if how == ''  ; implement later for other possible ranking methods
        self.weeklyAvg()

        data = self.data
        filter_t = data[(data['firstWeekID'] < upperBound) & (data['lastWeekID'] > lowerBound)]
        filter_g = filter_t[filter_t.spotify_genre.apply(lambda x: bool(set(x) & set(genre)))]
        
        playlist = filter_g.sort_values(['Instance','Avg Weekly','Weeks on Chart'], ascending=[True,True,False]).reset_index(drop=True)
        return playlist[playlist.columns[0:5]][:length]

x = billboard()
play = x.getList(startY=1970, endY=2000, genre=['rap','trap'])
play
# t1 = time.time()
# t1-t0
# Out:
#                                                SongID  \
# 0                                  Hey LoverLL Cool J
# 1           No DiggityBLACKstreet (Featuring Dr. Dre)
# 2                                  Ms. JacksonOutKast
# 3                          Baby Got BackSir Mix-A-Lot
# 4                                    Feel So GoodMase
# 5                              Good EnoughBobby Brown
# 6                           Humpin' AroundBobby Brown
# 7                                    ShoopSalt-N-Pepa
# 8   Mo Money Mo ProblemsThe Notorious B.I.G. Featu...
# 9                Case Of The Ex (Whatcha Gonna Do)Mya
# 10                                    I Wanna KnowJoe
# 11                     Mr. WendalArrested Development
# 12           Whatta ManSalt-N-Pepa Featuring En Vogue
# 13                             Fantastic VoyageCoolio
# 14                         Rump ShakerWreckx-N-Effect
# 15                    Hip Hop HoorayNaughty By Nature
# 16                            O.P.P.Naughty By Nature
#  '5DOYik1z3Of1wAFfY3dYbC',
#  '7sJN693sYKEIEMu7fc5VnJ',
#  '3QlTzofanSqDWywxEzGGE2',
#  '4dY4JVC0Q9CwpeZ6JAclIc',
#  '1w29UTa5uUvIri2tWtZ12Y',
#  '7EIEKNu2WrzeocMcNojz7z',
#  '0s46SltT4On0Z6kglK1I5c',
#  '6hxn98poTu1O4YZfafvC18',
#  '0UN5OvKlbg06LnZyVk48ll',
#  '6m59VvDUi0UQsB2eZ9wVbH',
#  '42OhQBFNIbMyxRGxyPOvQA',
#  '2dieHErJLwG7fOzD8WAtFO',
#  '3aln8WgAUps6efYtdEYxP3',
#  '3TZwjdclvWt7iPJUnMpgcs',
#  '4IYKjN1DrYzxKXt0umJqsG',
#  '0OvwzS8FX73Bw7ykMRmffU',
#  '7KwZNVEaqikRSBSpyhXK2j',
#  '6zOg9gP62RJSsKFeOBAgvH',
#  '2rkVoKVEMuct8SmEIGKzBw']

# %%
# !pip install spotipy --upgrade
# Out:
# Requirement already up-to-date: spotipy in /Users/nayoung/opt/anaconda3/lib/python3.8/site-packages (2.16.1)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /Users/nayoung/opt/anaconda3/lib/python3.8/site-packages (from spotipy) (1.15.0)
# Requirement already satisfied, skipping upgrade: requests>=2.20.0 in /Users/nayoung/opt/anaconda3/lib/python3.8/site-packages (from spotipy) (2.24.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/nayoung/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->spotipy) (1.25.11)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /Users/nayoung/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->spotipy) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /Users/nayoung/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->spotipy) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/nayoung/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->spotipy) (2020.6.20)

# %%
SPOTIPY_CLIENT_ID='608e3b1bcba14f8bb1ed22fa44291d13'
SPOTIPY_CLIENT_SECRET='848e0d68cf6a4d00b07f583a69aa35dd'

import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET))

# %%
sp.tracks(tracks=playlist['spotify_track_id'].to_list()[:10], market=None)
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1P8IfcNKwrkQP5xJWuhaOC'},
#       'href': 'https://api.spotify.com/v1/artists/1P8IfcNKwrkQP5xJWuhaOC',
#       'id': '1P8IfcNKwrkQP5xJWuhaOC',
#       'name': 'LL Cool J',
#       'type': 'artist',
#       'uri': 'spotify:artist:1P8IfcNKwrkQP5xJWuhaOC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6b7NVGKHlwKyQzFKoVTaMA'},
#     'href': 'https://api.spotify.com/v1/albums/6b7NVGKHlwKyQzFKoVTaMA',
#     'id': '6b7NVGKHlwKyQzFKoVTaMA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27318a12da5d84a8f12312698ab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0218a12da5d84a8f12312698ab',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485118a12da5d84a8f12312698ab',
#       'width': 64}],
#     'name': 'Mr. Smith (Deluxe Edition)',
#     'release_date': '1995-11-20',
#     'release_date_precision': 'day',
#     'total_tracks': 23,
#     'type': 'album',
#     'uri': 'spotify:album:6b7NVGKHlwKyQzFKoVTaMA'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1P8IfcNKwrkQP5xJWuhaOC'},
#      'href': 'https://api.spotify.com/v1/artists/1P8IfcNKwrkQP5xJWuhaOC',
#      'id': '1P8IfcNKwrkQP5xJWuhaOC',
#      'name': 'LL Cool J',
#      'type': 'artist',
#      'uri': 'spotify:artist:1P8IfcNKwrkQP5xJWuhaOC'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6O74knDqdv3XaWtkII7Xjp'},
#      'href': 'https://api.spotify.com/v1/artists/6O74knDqdv3XaWtkII7Xjp',
#      'id': '6O74knDqdv3XaWtkII7Xjp',
#      'name': 'Boyz II Men',
#      'type': 'artist',
#      'uri': 'spotify:artist:6O74knDqdv3XaWtkII7Xjp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 284693,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMO10000243'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5wG7d4cNogw0ETKaICPEYA'},
#    'href': 'https://api.spotify.com/v1/tracks/5wG7d4cNogw0ETKaICPEYA',
#    'id': '5wG7d4cNogw0ETKaICPEYA',
#    'is_local': False,
#    'name': 'Hey Lover',
#    'popularity': 59,
#    'preview_url': None,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:5wG7d4cNogw0ETKaICPEYA'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2P3cjUru4H3fhSXXNxE9kA'},
#       'href': 'https://api.spotify.com/v1/artists/2P3cjUru4H3fhSXXNxE9kA',
#       'id': '2P3cjUru4H3fhSXXNxE9kA',
#       'name': 'Blackstreet',
#       'type': 'artist',
#       'uri': 'spotify:artist:2P3cjUru4H3fhSXXNxE9kA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2zGZLQiFl9UubtrVmtIkbi'},
#     'href': 'https://api.spotify.com/v1/albums/2zGZLQiFl9UubtrVmtIkbi',
#     'id': '2zGZLQiFl9UubtrVmtIkbi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27303ca37157b9ceefbe8fe225b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0203ca37157b9ceefbe8fe225b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485103ca37157b9ceefbe8fe225b',
#       'width': 64}],
#     'name': 'Another Level',
#     'release_date': '1996-09-09',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:2zGZLQiFl9UubtrVmtIkbi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2P3cjUru4H3fhSXXNxE9kA'},
#      'href': 'https://api.spotify.com/v1/artists/2P3cjUru4H3fhSXXNxE9kA',
#      'id': '2P3cjUru4H3fhSXXNxE9kA',
#      'name': 'Blackstreet',
#      'type': 'artist',
#      'uri': 'spotify:artist:2P3cjUru4H3fhSXXNxE9kA'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6DPYiyq5kWVQS4RGwxzPC7'},
#      'href': 'https://api.spotify.com/v1/artists/6DPYiyq5kWVQS4RGwxzPC7',
#      'id': '6DPYiyq5kWVQS4RGwxzPC7',
#      'name': 'Dr. Dre',
#      'type': 'artist',
#      'uri': 'spotify:artist:6DPYiyq5kWVQS4RGwxzPC7'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VbIlorLz3I5SEtIsc5vAr'},
#      'href': 'https://api.spotify.com/v1/artists/0VbIlorLz3I5SEtIsc5vAr',
#      'id': '0VbIlorLz3I5SEtIsc5vAr',
#      'name': 'Queen Pen',
#      'type': 'artist',
#      'uri': 'spotify:artist:0VbIlorLz3I5SEtIsc5vAr'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 304600,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR19600978'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6MdqqkQ8sSC0WB4i8PyRuQ'},
#    'href': 'https://api.spotify.com/v1/tracks/6MdqqkQ8sSC0WB4i8PyRuQ',
#    'id': '6MdqqkQ8sSC0WB4i8PyRuQ',
#    'is_local': False,
#    'name': 'No Diggity',
#    'popularity': 74,
#    'preview_url': None,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6MdqqkQ8sSC0WB4i8PyRuQ'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1G9G7WwrXka3Z1r7aIDjI7'},
#       'href': 'https://api.spotify.com/v1/artists/1G9G7WwrXka3Z1r7aIDjI7',
#       'id': '1G9G7WwrXka3Z1r7aIDjI7',
#       'name': 'Outkast',
#       'type': 'artist',
#       'uri': 'spotify:artist:1G9G7WwrXka3Z1r7aIDjI7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2tm3Ht61kqqRZtIYsBjxEj'},
#     'href': 'https://api.spotify.com/v1/albums/2tm3Ht61kqqRZtIYsBjxEj',
#     'id': '2tm3Ht61kqqRZtIYsBjxEj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732350e31bc346a6c20e9de166',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022350e31bc346a6c20e9de166',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512350e31bc346a6c20e9de166',
#       'width': 64}],
#     'name': 'Stankonia',
#     'release_date': '2000-10-31',
#     'release_date_precision': 'day',
#     'total_tracks': 24,
#     'type': 'album',
#     'uri': 'spotify:album:2tm3Ht61kqqRZtIYsBjxEj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1G9G7WwrXka3Z1r7aIDjI7'},
#      'href': 'https://api.spotify.com/v1/artists/1G9G7WwrXka3Z1r7aIDjI7',
#      'id': '1G9G7WwrXka3Z1r7aIDjI7',
#      'name': 'Outkast',
#      'type': 'artist',
#      'uri': 'spotify:artist:1G9G7WwrXka3Z1r7aIDjI7'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 270506,
#    'explicit': True,
#    'external_ids': {'isrc': 'USLF20000357'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0I3q5fE6wg7LIfHGngUTnV'},
#    'href': 'https://api.spotify.com/v1/tracks/0I3q5fE6wg7LIfHGngUTnV',
#    'id': '0I3q5fE6wg7LIfHGngUTnV',
#    'is_local': False,
#    'name': 'Ms. Jackson',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/07495099ccc8efb86eec89db4a3a95e03385921d?cid=608e3b1bcba14f8bb1ed22fa44291d13',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:0I3q5fE6wg7LIfHGngUTnV'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TQ9JTBI2n2hfo7aRONEYV'},
#       'href': 'https://api.spotify.com/v1/artists/3TQ9JTBI2n2hfo7aRONEYV',
#       'id': '3TQ9JTBI2n2hfo7aRONEYV',
#       'name': 'Sir Mix-A-Lot',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TQ9JTBI2n2hfo7aRONEYV'}],
#     'available_markets': ['AD',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KZ',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6c62jxWCe2aisIudaDRcaP'},
#     'href': 'https://api.spotify.com/v1/albums/6c62jxWCe2aisIudaDRcaP',
#     'id': '6c62jxWCe2aisIudaDRcaP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f82c7e4376cf8267fb396b7d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f82c7e4376cf8267fb396b7d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f82c7e4376cf8267fb396b7d',
#       'width': 64}],
#     'name': 'Mack Daddy',
#     'release_date': '1992-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:6c62jxWCe2aisIudaDRcaP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TQ9JTBI2n2hfo7aRONEYV'},
#      'href': 'https://api.spotify.com/v1/artists/3TQ9JTBI2n2hfo7aRONEYV',
#      'id': '3TQ9JTBI2n2hfo7aRONEYV',
#      'name': 'Sir Mix-A-Lot',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TQ9JTBI2n2hfo7aRONEYV'}],
#    'available_markets': ['AD',
#     'AL',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CR',
#     'CZ',
#     'DE',
#     'DK',
#     'EC',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'HK',
#     'HR',
#     'HU',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'JP',
#     'KZ',
#     'LI',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MY',
#     'NL',
#     'NO',
#     'NZ',
#     'PL',
#     'PT',
#     'RO',
#     'RS',
#     'RU',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'TH',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 262826,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM19100221'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1SAkL1mYNJlaqnBQxVZrRl'},
#    'href': 'https://api.spotify.com/v1/tracks/1SAkL1mYNJlaqnBQxVZrRl',
#    'id': '1SAkL1mYNJlaqnBQxVZrRl',
#    'is_local': False,
#    'name': 'Baby Got Back',
#    'popularity': 66,
#    'preview_url': None,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1SAkL1mYNJlaqnBQxVZrRl'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wiBLzTI7z9RUwEpNPdFT6'},
#       'href': 'https://api.spotify.com/v1/artists/1wiBLzTI7z9RUwEpNPdFT6',
#       'id': '1wiBLzTI7z9RUwEpNPdFT6',
#       'name': 'Mase',
#       'type': 'artist',
#       'uri': 'spotify:artist:1wiBLzTI7z9RUwEpNPdFT6'}],
#     'available_markets': ['AD',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'KZ',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/21YtqAiqXNGuvWNBS0JvOy'},
#     'href': 'https://api.spotify.com/v1/albums/21YtqAiqXNGuvWNBS0JvOy',
#     'id': '21YtqAiqXNGuvWNBS0JvOy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b950e2fa6cd0f5c0767b6650',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b950e2fa6cd0f5c0767b6650',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b950e2fa6cd0f5c0767b6650',
#       'width': 64}],
#     'name': 'Harlem World',
#     'release_date': '1997',
#     'release_date_precision': 'year',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:21YtqAiqXNGuvWNBS0JvOy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wiBLzTI7z9RUwEpNPdFT6'},
#      'href': 'https://api.spotify.com/v1/artists/1wiBLzTI7z9RUwEpNPdFT6',
#      'id': '1wiBLzTI7z9RUwEpNPdFT6',
#      'name': 'Mase',
#      'type': 'artist',
#      'uri': 'spotify:artist:1wiBLzTI7z9RUwEpNPdFT6'}],
#    'available_markets': ['AD',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'KW',
#     'KZ',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'RO',
#     'RS',
#     'RU',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 203626,
#    'explicit': True,
#    'external_ids': {'isrc': 'USBB40580127'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7hfRrdFJgFKK3cJ4rmkecE'},
#    'href': 'https://api.spotify.com/v1/tracks/7hfRrdFJgFKK3cJ4rmkecE',
#    'id': '7hfRrdFJgFKK3cJ4rmkecE',
#    'is_local': False,
#    'name': 'Feel so Good',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/555687cf1db6af866ba108904b14c108ea73b374?cid=608e3b1bcba14f8bb1ed22fa44291d13',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:7hfRrdFJgFKK3cJ4rmkecE'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62sPt3fswraiEPnKQpAbdE'},
#       'href': 'https://api.spotify.com/v1/artists/62sPt3fswraiEPnKQpAbdE',
#       'id': '62sPt3fswraiEPnKQpAbdE',
#       'name': 'Bobby Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:62sPt3fswraiEPnKQpAbdE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6MBpIrXaNMdoTNrWchRpO7'},
#     'href': 'https://api.spotify.com/v1/albums/6MBpIrXaNMdoTNrWchRpO7',
#     'id': '6MBpIrXaNMdoTNrWchRpO7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273706965d1da3fb77d19fe421f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02706965d1da3fb77d19fe421f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851706965d1da3fb77d19fe421f',
#       'width': 64}],
#     'name': 'Bobby',
#     'release_date': '1992-08-24',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:6MBpIrXaNMdoTNrWchRpO7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62sPt3fswraiEPnKQpAbdE'},
#      'href': 'https://api.spotify.com/v1/artists/62sPt3fswraiEPnKQpAbdE',
#      'id': '62sPt3fswraiEPnKQpAbdE',
#      'name': 'Bobby Brown',
#      'type': 'artist',
#      'uri': 'spotify:artist:62sPt3fswraiEPnKQpAbdE'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 302093,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMC19938670'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3WFQ6pEp1BRXrDKQ825ze7'},
#    'href': 'https://api.spotify.com/v1/tracks/3WFQ6pEp1BRXrDKQ825ze7',
#    'id': '3WFQ6pEp1BRXrDKQ825ze7',
#    'is_local': False,
#    'name': 'Good Enough',
#    'popularity': 45,
#    'preview_url': None,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:3WFQ6pEp1BRXrDKQ825ze7'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62sPt3fswraiEPnKQpAbdE'},
#       'href': 'https://api.spotify.com/v1/artists/62sPt3fswraiEPnKQpAbdE',
#       'id': '62sPt3fswraiEPnKQpAbdE',
#       'name': 'Bobby Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:62sPt3fswraiEPnKQpAbdE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/

#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fde79b88e2a659c394c5ae30',
#       'width': 64}],
#     'name': 'Life After Death (2014 Remastered Edition)',
#     'release_date': '1997-03-04',
#     'release_date_precision': 'day',
#     'total_tracks': 24,
#     'type': 'album',
#     'uri': 'spotify:album:7dRdaGSxgcBdJnrOviQRuB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5me0Irg2ANcsgc93uaYrpb'},
#      'href': 'https://api.spotify.com/v1/artists/5me0Irg2ANcsgc93uaYrpb',
#      'id': '5me0Irg2ANcsgc93uaYrpb',
#      'name': 'The Notorious B.I.G.',
#      'type': 'artist',
#      'uri': 'spotify:artist:5me0Irg2ANcsgc93uaYrpb'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1wiBLzTI7z9RUwEpNPdFT6'},
#      'href': 'https://api.spotify.com/v1/artists/1wiBLzTI7z9RUwEpNPdFT6',
#      'id': '1wiBLzTI7z9RUwEpNPdFT6',
#      'name': 'Mase',
#      'type': 'artist',
#      'uri': 'spotify:artist:1wiBLzTI7z9RUwEpNPdFT6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/59wfkuBoNyhDMQGCljbUbA'},
#      'href': 'https://api.spotify.com/v1/artists/59wfkuBoNyhDMQGCljbUbA',
#      'id': '59wfkuBoNyhDMQGCljbUbA',
#      'name': 'Diddy',
#      'type': 'artist',
#      'uri': 'spotify:artist:59wfkuBoNyhDMQGCljbUbA'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 257399,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT21402732'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4INDiWSKvqSKDEu7mh8HFz'},
#    'href': 'https://api.spotify.com/v1/tracks/4INDiWSKvqSKDEu7mh8HFz',
#    'id': '4INDiWSKvqSKDEu7mh8HFz',
#    'is_local': False,
#    'name': 'Mo Money Mo Problems (feat. Puff Daddy & Mase) - 2014 Remaster',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0260fcbb89863c7da1358ce217fe20dc5b8416e7?cid=608e3b1bcba14f8bb1ed22fa44291d13',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:4INDiWSKvqSKDEu7mh8HFz'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lHL3ubAMgSasKjNqKb8HF'},
#       'href': 'https://api.spotify.com/v1/artists/6lHL3ubAMgSasKjNqKb8HF',
#       'id': '6lHL3ubAMgSasKjNqKb8HF',
#       'name': 'Mýa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6lHL3ubAMgSasKjNqKb8HF'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4LPScJnCr71D6oXB1MfQJ7'},
#     'href': 'https://api.spotify.com/v1/albums/4LPScJnCr71D6oXB1MfQJ7',
#     'id': '4LPScJnCr71D6oXB1MfQJ7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737c72c7888e7fe0b6ef7cb94a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027c72c7888e7fe0b6ef7cb94a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517c72c7888e7fe0b6ef7cb94a',
#       'width': 64}],
#     'name': 'Fear Of Flying',
#     'release_date': '2000-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:4LPScJnCr71D6oXB1MfQJ7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lHL3ubAMgSasKjNqKb8HF'},
#      'href': 'https://api.spotify.com/v1/artists/6lHL3ubAMgSasKjNqKb8HF',
#      'id': '6lHL3ubAMgSasKjNqKb8HF',
#      'name': 'Mýa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6lHL3ubAMgSasKjNqKb8HF'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'disc_number': 1,
#    'duration_ms': 236826,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR10000805'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1ak0S3NhwWrUgNlQhJ1412'},
#    'href': 'https://api.spotify.com/v1/tracks/1ak0S3NhwWrUgNlQhJ1412',
#    'id': '1ak0S3NhwWrUgNlQhJ1412',
#    'is_local': False,
#    'name': 'Case Of The Ex (Whatcha Gonna Do)',
#    'popularity': 52,
#    'preview_url': None,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1ak0S3NhwWrUgNlQhJ1412'}]}
